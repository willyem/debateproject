# %%
import processing
import pandas as pd
import string 
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import nltk.data
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import pos_tag
from sklearn.cross_validation import train_test_split
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
# Out:
# [autoreload of processing failed: Traceback (most recent call last):
#   File "/Users/datascientist/anaconda/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "processing.py", line 72
#     aga_motion_text, lc_aga, ac_aga, aga_pol, aga_subj \
#                                                         ^
# SyntaxError: unexpected character after line continuation character
# ]

# %%
names_and_win = [('campus_assault.txt', [0, 1]),('samesex.txt', [0, 1]), ('iran_deal.txt', [0, 1]),\
('death_penalty.txt', [0, 1]), ('constitutional_authority.txt', [0, 1]), ('right_to_forget.txt', [0, 1]), \
('liberals_stifling.txt', [1, 0]), ('declinists.txt', [1, 0]), ('amazon.txt', [0, 1]), ('gmos.txt', [1, 0]), ('eutha.txt', [0, 1]), \
('income_inequal.txt', [0, 1]), ('mass_collection.txt', [1, 0]), ('flexing_musc.txt', [1, 0]), ('common_core.txt', [1, 0]), \
('pacs.txt', [0, 1]), ('death_not_final.txt', [0, 1]), ('millenials.txt', [1, 0]), ('lecture_obsolete.txt', [1, 0]), \
('russia.txt', [0, 1]), ('USA_kill.txt', [1, 0]), ('affirmative.txt', [1, 0]), ('snowden.txt', [1, 0]), ('obamacare.txt', [1, 0]), \
('eat_face.txt', [1, 0]), ('spy_on_me.txt', [0, 1]), ('right_to_bear.txt', [1, 0]), ('take_job_anywhere.txt', [0, 1]), \
('red_state.txt', [1, 0]), ('break_up_banks.txt', [0, 1]), ('drones.txt', [0, 1]), ('us_syria.txt', [1, 0]), \
('pentagon_budget.txt', [0, 1]), ('fda_caution.txt', [1, 0]), ('gop_center.txt', [0, 1]), ('minimum_wage.txt', [0, 1]), \
('strong_dollar.txt', [1, 0]), ('prohibit_genetic.txt', [0, 1]), ('nuclear_iran.txt', [0, 1]), ('science_god.txt', [1, 0]), \
('legalize_drugs.txt', [1, 0]), ('rich_taxed.txt', [0, 1]), ('end_of_life_care.txt', [1, 0]), ('elected_islamists.txt', [0, 1]),\
('money_politics_overregulated.txt', [0, 1]), ('natural_gas_bad.txt', [1, 0]), ('ban_football.txt', [1, 0]), \
('internet_closing_minds.txt', [1, 0]), ('china_capitalism_better.txt', [0, 1]), ('obesity_govt_business.txt', [0, 1]), \
('palestine_statehood.txt', [1, 0]), ('no_religion.txt', [1, 0]), ('job_plan.txt', [1, 0]), ('too_many_kids_college.txt', [1, 0]), \
('grandmas_benefits.txt', [0, 1]), ('men_are_finished.txt', [1, 0]), ('end_war_on_terror.txt', [0, 1]), \
('freedom_press_state.txt', [0, 1]), ('dont_give_us.txt', [1, 0]), ('clip_americas_wings.txt', [1, 0]), \
('clean_energy.txt', [0, 1]), ('two_party_bad.txt', [0, 1]), ('repeal_obamacare.txt', [0, 1]), ('airports_profiling.txt', [1, 0]), \
('afghanistan_lost.txt', [0, 1]), ('big_govt_stifling.txt', [1, 0]), ('islam_is_peace.txt', [0, 1]), \
('terrorists_enemy_combatants.txt', [0, 1]), ('cyber_war_exaggerated.txt', [0, 1]), ('obamas_policy_us_decline.txt', [0, 1]), \
('organic_is_hype.txt', [0, 1]), ('teacher_unions_failing_schools.txt', [0, 1]), ('us_stepback_israel.txt', [1, 0]), \
('california_failed.txt', [1, 0]), ('us_mexico_drugs.txt', [1, 0]), ('obamas_policies_working.txt', [1, 0]), \
('good_riddance_mainstream.txt', [0, 1]), ('us_will_not_succeed_afghan.txt', [0, 1]), ('buy_american_bad.txt', [1, 0]), \
('diplomacy_iran_nowhere.txt', [0, 1]), ('pay_for_sex.txt', [1, 0]), ('blame_washington_financial.txt', [1, 0]), \
('art_market_ethical.txt', [1, 0]), ('carbon_reductions_not_worth_it.txt', [1, 0]), ('bush_is_worst.txt', [0, 1]), \
('google_dont_be_evil.txt', [1, 0]), ('guns_reduce_crime.txt', [1, 0]), ('america_winning_iraq.txt', [1, 0]), \
('universal_health.txt', [0, 1]), ('legalize_organs.txt', [1, 0]), ('islam_radicals.txt', [1, 0]), \
('tough_interrogation.txt', [0, 1]), ('america_policeman.txt', [1, 0]), ('performance_enhancing.txt', [1, 0]), \
('aid_africa_bad.txt', [0, 1]), ('end_affirmative.txt', [0, 1]), ('russia_enemy_again.txt', [0, 1]), \
('stop_welcoming_immigrants.txt', [1, 0]), ('spread_democracy_me.txt', [1, 0]), ('booming_china.txt', [0, 1]), \
('more_domestic_surveillance.txt', [0, 1]), ('global_warming_not.txt', [1, 0]), ('america_too_religious.txt', [1, 0]), \
('hollywood_anti_us.txt', [0, 1]), ('democratic_hamas.txt', [0, 1]), ('license_to_offend.txt', [1, 0]), \
('tolerate_iran.txt', [1, 0])]

# %%
df = pd.DataFrame(columns = ["For_text", "FL", "FA", "FP", "FS", \
                             "Against_text", "AL", "AA", "AP", "AS"])

# %%
for document in names_and_win: 
    for_, aga_ = processing.parse_text('debate_text/'+document[0]) #/document
    print document 
    print "For the motion order: ", for_
    print "Against the motion order: ", aga_ 
    print "***********"
# Out:
# ('campus_assault.txt', [0, 1])
# For the motion order:  ['Jed Rubenfeld:', 'Jeannie Suk:']
# Against the motion order:  ['Michelle Anderson:', 'Stephen Schulhofer:']
# ***********
# ('samesex.txt', [0, 1])
# For the motion order:  ['John Eastman:', 'Sherif Girgis:']
# Against the motion order:  ['Kenji Yoshino:', 'Evan Wolfson:']
# ***********
# ('iran_deal.txt', [0, 1])
# For the motion order:  ['Philip Gordon:', 'Thomas Pickering:']
# Against the motion order:  ['Michael Doran:', 'Mark Dubowitz:']
# ***********
# ('death_penalty.txt', [0, 1])
# For the motion order:  ['Diann Rust-Tierney:', 'Barry Scheck:']
# Against the motion order:  ['Robert Blecker:', 'Kent Scheidegger:']
# ***********
# ('constitutional_authority.txt', [0, 1])
# For the motion order:  ['Gene Healy:', 'Deborah Pearlstein:']
# Against the motion order:  ['Akhil Amar:', 'Philip Bobbitt:']
# ***********
# ('right_to_forget.txt', [0, 1])
# For the motion order:  ['Paul Nemitz:', 'Eric Posner:']
# Against the motion order:  ['Jonathan Zittrain:', 'Andrew McLaughlin:']
# ***********
# ('liberals_stifling.txt', [1, 0])
# For the motion order:  ['Greg Lukianoff:', 'Kirsten Powers:']
# Against the motion order:  ['Angus Johnston:', 'Jeremy Mayer:']
# ***********
# ('declinists.txt', [1, 0])
# For the motion order:  ['Josef Joffe:', 'Peter Zeihan:']
# Against the motion order:  ['Chrystia Freeland:', 'James Rickards:']
# ***********
# ('amazon.txt', [0, 1])
# For the motion order:  ['Joe Konrath:', 'Matthew Yglesias:']
# Against the motion order:  ['Franklin Foer:', 'Scott Turow:']
# ***********
# ('gmos.txt', [1, 0])
# For the motion order:  ['Robert Fraley:', 'Alison Van Eenennaam:']
# Against the motion order:  ['Charles Benbrook:', 'Margaret Mellon:']
# ***********
# ('eutha.txt', [0, 1])
# For the motion order:  ['Peter Singer:', 'Andrew Solomon:']
# Against the motion order:  ['Ilora Finlay:', 'Daniel Sulmasy:']
# ***********
# ('income_inequal.txt', [0, 1])
# For the motion order:  ['Elise Gould:', 'Nick Hanauer:']
# Against the motion order:  ['Edward Conard:', 'Scott Winship:']
# ***********
# ('mass_collection.txt', [1, 0])
# For the motion order:  ['Alex Abdo:', 'Elizabeth Wydra:']
# Against the motion order:  ['Stewart Baker:', 'John Yoo:']
# ***********
# ('flexing_musc.txt', [1, 0])
# For the motion order:  ['Aaron David Miller:', 'Paul Pillar:']
# Against the motion order:  ['Michael Doran:', 'Bret Stephens:']
# ***********
# ('common_core.txt', [1, 0])
# For the motion order:  ['Carmel Martin:', 'Michael Petrilli:']
# Against the motion order:  ['Carol Burris:', 'Fredrick Hess:']
# ***********
# ('pacs.txt', [0, 1])
# For the motion order:  ['Floyd Abrams:', 'Nadine Strossen:']
# Against the motion order:  ['Burt Neuborne:', 'Zephyr Teachout:']
# ***********
# ('death_not_final.txt', [0, 1])
# For the motion order:  ['Eben Alexander:', 'Raymond Moody:']
# Against the motion order:  ['Sean Carroll:', 'Steven Novella:']
# ***********
# ('millenials.txt', [1, 0])
# For the motion order:  ['Binta Niambi Brown:', 'Keith Campbell:']
# Against the motion order:  ['David Burnstein:', 'Jessica Grose:']
# ***********
# ('lecture_obsolete.txt', [1, 0])
# For the motion order:  ['Anant Agarwal:', 'Ben Nelson:']
# Against the motion order:  ['Jonathan Cole:', 'Rebecca Schuman:']
# ***********
# ('russia.txt', [0, 1])
# For the motion order:  ['Ian Bremmer:', 'Edward Lucas:']
# Against the motion order:  ['Robert Blackwill:', 'Peter Hitchens:']
# ***********
# ('USA_kill.txt', [1, 0])
# For the motion order:  ['Alan Dershowitz:', 'Michael Lewis:']
# Against the motion order:  ['Noah Feldman:', 'Hina Shamsi:']
# ***********
# ('affirmative.txt', [1, 0])
# For the motion order:  ['Gail Heriot:', 'Richard Sander:']
# Against the motion order:  ['Theodore Shaw:', 'Randall Kennedy:']
# ***********
# ('snowden.txt', [1, 0])
# For the motion order:  ['Daniel Ellsberg:', 'Ben Wizner:']
# Against the motion order:  ['Andrew McCarthy:', 'James Woolsey:']
# ***********
# ('obamacare.txt', [1, 0])
# For the motion order:  ['Scott Gottlieb:', 'Megan McArdle:']
# Against the motion order:  ['Jonathan Chait:', 'Douglas Kamerow:']
# ***********
# ('eat_face.txt', [1, 0])
# For the motion order:  ['Neal Barnard:', 'Gene Baur:']
# Against the motion order:  ['Chris Masterjohn:', 'Joel Salatin:']
# ***********
# ('spy_on_me.txt', [0, 1])
# For the motion order:  ['Stewart Baker:', 'Richard Falkenrath:']
# Against the motion order:  ['David Cole:', 'Michael German:']
# ***********
# ('right_to_bear.txt', [1, 0])
# For the motion order:  ['Alan Dershowitz:', 'Sanford Levinson:']
# Against the motion order:  ['David Kopel:', 'Eugene Volokh:']
# ***********
# ('take_job_anywhere.txt', [0, 1])
# For the motion order:  ['Bryan Caplan:', 'Vivek Wadhwa:']
# Against the motion order:  ['Kathleen Newland:', 'Ron Unz:']
# ***********
# ('red_state.txt', [1, 0])
# For the motion order:  ['Hugh Hewitt:', 'Stephen Moore:']
# Against the motion order:  ['Gray Davis:', 'Michael Lind:']
# ***********
# ('break_up_banks.txt', [0, 1])
# For the motion order:  ['Richard Fisher:', 'Simon Johnson:']
# Against the motion order:  ['Douglas Elliott:', 'Paul Saltzman:']
# ***********
# ('drones.txt', [0, 1])
# For the motion order:  ['Ahmed Rashid:', 'John Kael Weston:']
# Against the motion order:  ['Dennis Blair:', 'Norton Schwartz:']
# ***********
# ('us_syria.txt', [1, 0])
# For the motion order:  ['Graham Allison:', 'Richard Falkenrath:']
# Against the motion order:  ['Nicholas Burns:', 'Nigel Sheinwald:']
# ***********
# ('pentagon_budget.txt', [0, 1])
# For the motion order:  ['Thomas Donnelly:', 'Andrew Krepinevich:']
# Against the motion order:  ['Benjamin Friedman:', 'Kori Schake:']
# ***********
# ('fda_caution.txt', [1, 0])
# For the motion order:  ['Scott Gottlieb:', 'Peter Huber:']
# Against the motion order:  ['Jerry Avorn:', 'David Challoner:']
# ***********
# ('gop_center.txt', [0, 1])
# For the motion order:  ['David Brooks:', 'Mickey Edwards:']
# Against the motion order:  ['Laura Ingraham:', 'Ralph Reed:']
# ***********
# ('minimum_wage.txt', [0, 1])
# For the motion order:  ['James Dorn:', 'Russell Roberts:']
# Against the motion order:  ['Jared Bernstein:', 'Karen Kornbluh:']
# ***********
# ('strong_dollar.txt', [1, 0])
# For the motion order:  ['Frederic Mishkin:', 'John Taylor:']
# Against the motion order:  ['James Grant:', 'Steve Forbes:']
# ***********
# ('prohibit_genetic.txt', [0, 1])
# For the motion order:  ['Sheldon Krimsky:', 'Lord Robert Winston:']
# Against the motion order:  ['Nita Farahany:', 'Lee Silver:']
# ***********
# ('nuclear_iran.txt', [0, 1])
# For the motion order:  ['James Dobbins:', 'Reuven Pedatzur:']
# Against the motion order:  ['Shmuel Bar:', 'Jeffrey Goldberg:']
# ***********
# ('science_god.txt', [1, 0])
# For the motion order:  ['Lawrence Krauss:', 'Michael Shermer:']
# Against the motion order:  ['Dinesh DSouza:', 'Ian Hutchinson:']
# ***********
# ('legalize_drugs.txt', [1, 0])
# For the motion order:  ['Paul Butler:', 'Nick Gillespie:']
# Against the motion order:  ['Theodore Dalrymple:', 'Asa Hutchinson:']
# ***********
# ('rich_taxed.txt', [0, 1])
# For the motion order:  ['Glenn Hubbard:', 'Arthur Laffer:']
# Against the motion order:  ['Robert Reich:', 'Mark Zandi:']
# ***********
# ('end_of_life_care.txt', [1, 0])
# For the motion order:  ['Arthur Kellermann:', 'Peter Singer:']
# Against the motion order:  ['Ken Connor:', 'Sally Pipes:']
# ***********
# ('elected_islamists.txt', [0, 1])
# For the motion order:  ['Reuel Marc Gerecht:', 'Brian Katulis:']
# Against the motion order:  ['Daniel Pipes:', 'Zuhdi Jasser:']
# ***********
# ('money_politics_overregulated.txt', [0, 1])
# For the motion order:  ['David Keating:', 'Jacob Sullum:']
# Against the motion order:  ['Trevor Potter:', 'Jonathan Soros:']
# ***********
# ('natural_gas_bad.txt', [1, 0])
# For the motion order:  ['Deborah Goldberg:', 'Katherine Hudson:']
# Against the motion order:  ['Joe Nocera:', 'Susan Tierney:']
# ***********
# ('ban_football.txt', [1, 0])
# For the motion order:  ['Buzz Bissinger:', 'Malcolm Gladwell:']
# Against the motion order:  ['Tim Green:', 'Jason Whitlock:']
# ***********
# ('internet_closing_minds.txt', [1, 0])
# For the motion order:  ['Eli Pariser:', 'Siva Vaidhyanathan:']
# Against the motion order:  ['Evgeny Morozov:', 'Jacob Weisberg:']
# ***********
# ('china_capitalism_better.txt', [0, 1])
# For the motion order:  ['Orville Schell:', 'Peter Schiff:']
# Against the motion order:  ['Ian Bremmer:', 'Minxin Pei:']
# ***********
# ('obesity_govt_business.txt', [0, 1])
# For the motion order:  ['Pamela Peeke:', 'David Satcher:']
# Against the motion order:  ['Paul Campos:', 'John Stossel:']
# ***********
# ('palestine_statehood.txt', [1, 0])
# For the motion order:  ['Mustafa Barghouthi:', 'Daniel Levy:']
# Against the motion order:  ['Dore Gold:', 'Aaron David Miller:']
# ***********
# ('no_religion.txt', [1, 0])
# For the motion order:  ['Matthew Chapman:', 'A.C. Grayling:']
# Against the motion order:  ['Dinesh DSouza:', 'David Wolpe:']
# ***********
# ('job_plan.txt', [1, 0])
# For the motion order:  ['Cecilia Rouse:', 'Mark Zandi:']
# Against the motion order:  ['Richard Epstein:', 'Daniel Mitchell:']
# ***********
# ('too_many_kids_college.txt', [1, 0])
# For the motion order:  ['Charles Murray:', 'Peter Thiel:']
# Against the motion order:  ['Henry Bienen:', 'Vivek Wadhwa:']
# ***********
# ('grandmas_benefits.txt', [0, 1])
# For the motion order:  ['Margaret Hoover:', 'Mort Zuckerman:']
# Against the motion order:  ['Howard Dean:', 'Jeff Madrick:']
# ***********
# ('men_are_finished.txt', [1, 0])
# For the motion order:  ['Dan Abrams:', 'Hanna Rosin:']
# Against the motion order:  ['Christina Hoff Sommers:', 'David Zinczenko:']
# ***********
# ('end_war_on_terror.txt', [0, 1])
# For the motion order:  ['Peter Bergen:', 'Juliette Kayyem:']
# Against the motion order:  ['Richard Falkenrath:', 'Michael Hayden:']
# ***********
# ('freedom_press_state.txt', [0, 1])
# For the motion order:  ['Michael Chertoff:', 'Gabriel Schoenfeld:']
# Against the motion order:  ['Alan Dershowitz:', 'David Sanger:']
# ***********
# ('dont_give_us.txt', [1, 0])
# For the motion order:  ['Kris Kobach:', 'Tom Tancredo:']
# Against the motion order:  ['Julian Castro:', 'Tamar Jacoby:']
# ***********
# ('clip_americas_wings.txt', [1, 0])
# For the motion order:  ['Peter Galbraith:', 'Lawrence Korb:']
# Against the motion order:  ['Elliott Abrams:', 'Eliot Cohen:']
# ***********
# ('clean_energy.txt', [0, 1])
# For the motion order:  ['Bill Ritter:', 'Kassia Yanosek:']
# Against the motion order:  ['Robert Bryce:', 'Steven Hayward:']
# ***********
# ('two_party_bad.txt', [0, 1])
# For the motion order:  ['David Brooks:', 'Arianna Huffington:']
# Against the motion order:  ['Zev Chafets:', 'P.J. ORourke:']
# ***********
# ('repeal_obamacare.txt', [0, 1])
# For the motion order:  ['Douglas Holtz-Eakin:', 'John Shadegg:']
# Against the motion order:  ['Jonathan Cohn:', 'Paul Starr:']
# ***********
# ('airports_profiling.txt', [1, 0])
# For the motion order:  ['Robert Baer:', 'Deroy Murdock:', 'Asra Nomani:']
# Against the motion order:  ['Hassan Abbas:', 'Debra Burlingame:', 'Michael Chertoff:']
# ***********
# ('afghanistan_lost.txt', [0, 1])
# For the motion order:  ['Matthew Hoh:', 'Nir Rosen:']
# Against the motion order:  ['Peter Bergen:', 'Max Boot:']
# ***********
# ('big_govt_stifling.txt', [1, 0])
# For the motion order:  ['Phil Gramm:', 'Art Laffer:']
# Against the motion order:  ['Nouriel Roubini:', 'Laura Tyson:']
# ***********
# ('islam_is_peace.txt', [0, 1])
# For the motion order:  ['Zeba Khan:', 'Maajid Nawaz:']
# Against the motion order:  ['Ayaan Hirsi Ali:', 'Douglas Murray:']
# ***********
# ('terrorists_enemy_combatants.txt', [0, 1])
# For the motion order:  ['Michael Hayden:', 'Marc Thiessen:']
# Against the motion order:  ['David Frakt:', 'Stephen Jones:']
# ***********
# ('cyber_war_exaggerated.txt', [0, 1])
# For the motion order:  ['Marc Rotenberg:', 'Bruce Schneier:']
# Against the motion order:  ['Mike McConnell:', 'Jonathan Zittrain:']
# ***********
# ('obamas_policy_us_decline.txt', [0, 1])
# For the motion order:  ['Dan Senor:', 'Mort Zuckerman:']
# Against the motion order:  ['Wesley Clark:', 'Bernard-Henri Levy:']
# ***********
# ('organic_is_hype.txt', [0, 1])
# For the motion order:  ['Dennis Avery:', 'Blake Hurst:', 'John Krebs:']
# Against the motion order:  ['Charles Benbrook:', 'Urvashi Rangan:', 'Jeffrey Steingarten:']
# ***********
# ('teacher_unions_failing_schools.txt', [0, 1])
# For the motion order:  ['Kate McLaughlin:', 'Gary Smuts:', 'Randi Weingarten:']
# Against the motion order:  ['Terry Moe:', 'Rod Paige:', 'Larry Sand:']
# ***********
# ('us_stepback_israel.txt', [1, 0])
# For the motion order:  ['Roger Cohen:', 'Rashid Khalidi:']
# Against the motion order:  ['Stuart Eizenstat:', 'Itamar Rabinovich:']
# ***********
# ('california_failed.txt', [1, 0])
# For the motion order:  ['Andreas Kluth:', 'Bobby Shriver:', 'Sharon Waxman:']
# Against the motion order:  ['Gray Davis:', 'Van Jones:', 'Lawrence ODonnell:']
# ***********
# ('us_mexico_drugs.txt', [1, 0])
# For the motion order:  ['Andres Martinez:', 'Jeffrey Miron:', 'Fareed Zakaria:']
# Against the motion order:  ['Jorge Castaneda:', 'Chris Cox:', 'Asa Hutchinson:']
# ***********
# ('obamas_policies_working.txt', [1, 0])
# For the motion order:  ['Lawrence Mishel:', 'Steve Rattner:', 'Mark Zandi:']
# Against the motion order:  ['James Galbraith:', 'Allan Meltzer:', 'Eliot Spitzer:']
# ***********
# ('good_riddance_mainstream.txt', [0, 1])
# For the motion order:  ['John Hockenberry:', 'Jim VandeHei:', 'Michael Wolff:']
# Against the motion order:  ['Phil Bronstein:', 'David Carr:', 'Katrina vanden Heuvel:']
# ***********
# ('us_will_not_succeed_afghan.txt', [0, 1])
# For the motion order:  ['Steve Clemons:', 'Patrick Lang:', 'Ralph Peters:']
# Against the motion order:  ['Steve Coll:', 'John Nagl:', 'James Shinn:']
# ***********
# ('buy_american_bad.txt', [1, 0])
# For the motion order:  ['Jagdish Bhagwati:', 'Douglas Irwin:', 'Susan Schwab:']
# Against the motion order:  ['Leo Gerard:', 'John MacArthur:', 'Jeff Madrick:']
# ***********
# ('diplomacy_iran_nowhere.txt', [0, 1])
# For the motion order:  ['Liz Cheney:', 'Dan Senor:']
# Against the motion order:  ['Nicholas Burns:', 'Kenneth Pollack:']
# ***********
# ('pay_for_sex.txt', [1, 0])
# For the motion order:  ['Melissa Farley:', 'Catharine MacKinnon:', 'Wendy Shalit:']
# Against the motion order:  ['Sydney Biddle Barrows:', 'Tyler Cowen:', 'Lionel Tiger:']
# ***********
# ('blame_washington_financial.txt', [1, 0])
# For the motion order:  ['Niall Ferguson:', 'John Steele Gordon:', 'Nouriel Roubini:']
# Against the motion order:  ['Alex Berenson:', 'Jim Chanos:', 'Nell Minow:']
# ***********
# ('art_market_ethical.txt', [1, 0])
# For the motion order:  ['Richard Feigen:', 'Michael Hue-Williams:', 'Adam Lindemann:']
# Against the motion order:  ['Amy Cappellazzo:', 'Chuck Close:', 'Jerry Saltz:']
# ***********
# ('carbon_reductions_not_worth_it.txt', [1, 0])
# For the motion order:  ['Peter Huber:', 'Bjorn Lomborg:', 'Philip Stott:']
# Against the motion order:  ['L. Hunter Lovins:', 'Oliver Tickell:', 'Adam Werbach:']
# ***********
# ('bush_is_worst.txt', [0, 1])
# For the motion order:  ['Simon Jenkins:', 'Jacob Weisberg:']
# Against the motion order:  ['William Kristol:', 'Karl Rove:']
# ***********
# ('google_dont_be_evil.txt', [1, 0])
# For the motion order:  ['Harry Lewis:', 'Randal Picker:', 'Siva Vaidhyanathan:']
# Against the motion order:  ['Esther Dyson:', 'Jim Harper:', 'Jeff Jarvis:']
# ***********
# ('guns_reduce_crime.txt', [1, 0])
# For the motion order:  ['Stephen Halbrook:', 'Gary Kleck:', 'John Lott:']
# Against the motion order:  ['John Donohue:', 'Paul Helmke:', 'Gil Kerlikowske:']
# ***********
# ('america_winning_iraq.txt', [1, 0])
# For the motion order:  ['Frederick Kagan:', 'Jack Keane:']
# Against the motion order:  ['Charles Ferguson:', 'Malcolm Rifkind:']
# ***********
# ('universal_health.txt', [0, 1])
# For the motion order:  ['Art Kellermann:', 'Paul Krugman:', 'Michael Rachlis:']
# Against the motion order:  ['Michael Cannon:', 'Sally Pipes:', 'John Stossel:']
# ***********
# ('legalize_organs.txt', [1, 0])
# For the motion order:  ['Lloyd Cohen:', 'Amy Friedman:', 'Sally Satel:']
# Against the motion order:  ['James Childress:', 'Francis Delmonico:', 'David Rothman:']
# ***********
# ('islam_radicals.txt', [1, 0])
# For the motion order:  ['Daveed Gartenstein-Ross:', 'Paul Marshall:', 'Asra Nomani:']
# Against the motion order:  ['Reza Aslan:', 'Richard Bulliet:', 'Edina Lekovic:']
# ***********
# ('tough_interrogation.txt', [0, 1])
# For the motion order:  ['Rick Francona:', 'Heather Mac Donald:', 'David Rivkin:']
# Against the motion order:  ['Jack Cloonan:', 'John Hutson:', 'Darius Rejali:']
# ***********
# ('america_policeman.txt', [1, 0])
# For the motion order:  ['Max Boot:', 'Michael Mandelbaum:', 'Douglas Murray:']
# Against the motion order:  ['Ian Bremmer:', 'Ellen Laipson:', 'Matthew Parris:']
# ***********
# ('performance_enhancing.txt', [1, 0])
# For the motion order:  ['Radley Balko:', 'Norman Fost:', 'Julian Savulescu:']
# Against the motion order:  ['George Michael:', 'Dale Murphy:', 'Richard Pound:']
# ***********
# ('aid_africa_bad.txt', [0, 1])
# For the motion order:  ['George Ayittey:', 'William Easterly:', 'David Rieff:']
# Against the motion order:  ['Payne Lucas:', 'John McArthur:', 'Gayle Smith:']
# ***********
# ('end_affirmative.txt', [0, 1])
# For the motion order:  ['John McWhorter:', 'Terence Pell:', 'Joseph Phillips:']
# Against the motion order:  ['Khin Mai Aung:', 'Kimberle Crenshaw:', 'Tim Wise:']
# ***********
# ('russia_enemy_again.txt', [0, 1])
# For the motion order:  ['Claudia Rosett:', 'Bret Stephens:', 'Michael Waller:']
# Against the motion order:  ['Nina Khrushcheva:', 'Robert Legvold:', 'Mark Medish:']
# ***********
# ('stop_welcoming_immigrants.txt', [1, 0])
# For the motion order:  ['Vernon Briggs:', 'Mark Krikorian:', 'Heather Mac Donald:']
# Against the motion order:  ['Daniel Griswold:', 'Enrique Morones:', 'Karen Narasaki:']
# ***********
# ('spread_democracy_me.txt', [1, 0])
# For the motion order:  ['Flynt Leverett:', 'Dimitri Simes:', 'Shibley Telhami:']
# Against the motion order:  ['Liz Cheney:', 'Danielle Pletka:', 'Natan Sharansky:']
# ***********
# ('booming_china.txt', [0, 1])
# For the motion order:  ['Bill Gertz:', 'John Mearsheimer:', 'Michael Pillsbury:']
# Against the motion order:  ['James McGregor:', 'Daniel Rosen:', 'Stapleton Roy:']
# ***********
# ('more_domestic_surveillance.txt', [0, 1])
# For the motion order:  ['David Frum:', 'Andrew McCarthy:', 'John Yoo:']
# Against the motion order:  ['Bob Barr:', 'Jeffrey Rosen:', 'Nadine Strossen:']
# ***********
# ('global_warming_not.txt', [1, 0])
# For the motion order:  ['Michael Crichton:', 'Richard Lindzen:', 'Philip Stott:']
# Against the motion order:  ['Brenda Ekwurzel:', 'Gavin Schmidt:', 'Richard Somerville:']
# ***********
# ('america_too_religious.txt', [1, 0])
# For the motion order:  ['Susan Jacoby:', 'Barry Lynn:', 'Alan Wolfe:']
# Against the motion order:  ['Jean Bethke Elshtain:', 'William Galston:', 'Albert Raboteau:']
# ***********
# ('hollywood_anti_us.txt', [0, 1])
# For the motion order:  ['James Hirsen:', 'Roger Kimball:', 'Joshua Muravchik:']
# Against the motion order:  ['Robin Bronk:', 'Robert Greenwald:', 'Richard Walter:']
# ***********
# ('democratic_hamas.txt', [0, 1])
# For the motion order:  ['Daniel Ayalon:', 'Steven Cook:', 'John OSullivan:']
# Against the motion order:  ['Stanley Cohen:', 'Mahmoud Ould Mohamedou:', 'Mark Perry:']
# ***********
# ('license_to_offend.txt', [1, 0])
# For the motion order:  ['Philip Gourevitch:', 'Christopher Hitchens:', 'Signe Wilkinson:']
# Against the motion order:  ['David Cesarani:', 'Daisy Khan:', 'Mari Matsuda:']
# ***********
# ('tolerate_iran.txt', [1, 0])
# For the motion order:  ['George Perkovich:', 'Karim Sadjadpour:', 'Sanam Vakil:']
# Against the motion order:  ['Patrick Clawson:', 'Reuel Marc Gerecht:', 'William Kristol:']
# ***********

# %%
i = 0
for document in names_and_win:
    
    df.loc[i] =  processing.parse_text('debate_text/'+document[0]) #/document
    i+= 1

# %%
df
# Out:
#                                               For_text  FL  FA        FP  \
# 0    [Well, I actually dont think so. No. But look,...   3   1  0.125437
# 1    [No more doubt on my mind on his views than on...   4   0  0.158526
# 2    [New light, John, I can.  After many, many rou...   9   2  0.155611
# 3    [Well, Id like to think Ive gotten better at m...   2   5  0.107073
# 4    [Well, Im afraid I dont have anything good to ...   4   1  0.110678
# 5    [I meant that there are limits to snooping, co...   4   1  0.098307
# 6    [I--its funny.  I actually think of myself as ...   4   0  0.075995
# 7    [Absolutely.  First of all, because it was a h...  32   6  0.096867
# 8    [Well, I hope they find me entertaining. [laug...  22   6  0.155220
# 9    [Well, thanks, John.  Yeah, that was a reward ...   3   4  0.149702
# 10   [Sure, in one sentence, utilitarianism is the ...   1   4  0.115259
# 11   [Yes. Well, not immediately, John, but we econ...   4   7  0.134885
# 12   [No, were still Verizon customers.  And I dont...   1   0  0.079354
# 13   [Baker -- Baker was one smart guy.  He had no ...   5   3  0.052437
# 14   [Well honestly John, we werent thinking about ...   5  10  0.128664
# 15   [I met some journalists.  A time came in the l...   1   6  0.149489
# 16   [Astonishing. "no way," at least not until I k...   2   4  0.079321
# 17   [It takes patience. [laughter] And compassion....  16   4  0.101948
# 18   [Its not a hard course.  It is an MIT hard cou...   6   0  0.144787
# 19   [Not entirely. The point being that Putin has ...  22   3  0.104003
# 20   [Free time, I wish.  I am busier than everwrit...   1   1  0.039064
# 21   [I think they will. I hope that it is not clos...   2   1  0.147943
# 22   [Well, its a pretty good demonstration of the ...   4   2  0.078783
# 23   [Well, its the reverse, its a problem.  Medica...   3   6  0.081604
# 24   [You know, I have to tell you, its like quitti...   7   7  0.089417
# 25   [Well, I may never be tan, but Im rested, and ...   2   1  0.100322
# 26   [Well, my high school teachers said the same t...   6   7  0.135666
# 27   [Probably a slight advantage.  Economists are ...  14   5  0.119642
# 28   [Thank you. Right guy, wrong wife.  I married ...  11   2  0.178598
# 29   [First, thanks for getting it anatomically cor...  30  12  0.067716
# ..                                                 ...  ..  ..       ...
# 77   [Thanks  Thank you, while I have a chance to p...  11  15  0.086284
# 78   [[APPLAUSE]  Thank you very much.  Let me just...  11   8  0.100295
# 79   [Well, dont hold it against me.  [LAUGHTER]  T...  11  12  0.066091
# 80   [It is not. Thank you.  [APPLAUSE]  Thanks.  S...   9  20  0.048279
# 81   [Well thank you very much indeed, ladies and g...  24  20  0.082907
# 82   [Thank you very much and thanks to everybody f...  27   6  0.105815
# 83   [Well, while he was running, Barack Obama was ...   9  34  0.092397
# 84   [Well ladies and gentlemen, I just heard a won...   6  18  0.087100
# 85   [Thank you.  [APPLAUSE]  Thank you all for bei...  15   5  0.049229
# 86   [Thank you, John.  Thank you.  [APPLAUSE]  Its...   1   4  0.076854
# 87   [Thank you very much, its an honor to be here,...   4   2  0.108528
# 88   [Thank you.  Actually, Im not a surgeon, I am ...  10   6  0.078235
# 89   [Ladies and gentlemen, I want to make the ques...   5   1  0.086571
# 90   [Its important before you cast your vote in th...   5   4  0.107084
# 91   [I think one of the points you were trying to ...   5   3  0.046144
# 92   [Thank you very much.  And first Id like to th...  13   4  0.085501
# 93   [Well, let me start by saying, for those of yo...   6   3  0.087806
# 94   [Hello, well first of all, uh, let me thank th...   5   5  0.090170
# 95   [I think that when we discuss, um, racial pref...   5   6  0.111342
# 96   [Thank you and good evening, um  [PAUSE]  For ...   5   3  0.095828
# 97   [Thank you very much.  Its a pleasure to be he...   6   4  0.003171
# 98   [Good evening.  Its a pleasure to kick off ton...   5   4  0.108495
# 99   [The question before the house is, Is a boomin...   7   5  0.091981
# 100  [Thank you. Thank you.  Thank you, thank you a...  19   4  0.104613
# 101  [The microphone goes up.  [LAUGHTER]  Before I...  14  11  0.077357
# 102  [I am not an ordained minister or a rabbi.  So...  14  19  0.109597
# 103  [Now that Pew Poll that uh, was cited by Robin...   2   5  0.090222
# 104  [Thank you very much.  Can you hear me?  Now s...   1   6  0.080822
# 105  [Extraordinary how people who want to silence ...  37  15  0.044091
# 106  [Thank you.  Im intrigued by the Dating Game i...   3   2  0.100149
#
#            FS                                       Against_text  AL  AA  \
# 0    0.571909  [I think it does. Over the past decade, the un...   0   2
# 1    0.507267  [I wish I could claim such prescience, John, b...   3   2
# 2    0.511137  [Theyre kissing a lot of frogs.  Its true. [la...  12   2
# 3    0.463843  [Well, first of all, I spent a lot more time w...   4   1
# 4    0.436728  [The American people.  Weve given our hearts a...   5   2
# 5    0.455648  [Well, we could end early and just hit the bar...   9   2
# 6    0.498153  [Actually, I was sitting quietly in a student ...   8   3
# 7    0.412933  [We are your friends.  We love America. And it...   6   6
# 8    0.505800  [It might be a touch obtuse for my opponents, ...  17  12
# 9    0.469912  [I am, John.  Weve -- were well prepared, Mard...   4   5
# 10   0.522650  [Well, I think its important to remember that ...   1   4
# 11   0.442770  [Only in my wildest dreams do I have that much...   7   1
# 12   0.424075  [Good to see you. [applause] Its a blessing bu...  11   3
# 13   0.404256  [Because its so contentious that if you say an...  17   5
# 14   0.480628  [Well, over half of my ninth graders last year...   5  10
# 15   0.489026  [Well, maybe theyre not getting it wrong.  Thi...   4   3
# 16   0.445563  [A naturalist is one who believes there is one...   9   8
# 17   0.508892  [I was 16. Yeah.  I didnt really think about t...   3   1
# 18   0.480108  [I began the fall of 1960.  I have never left,...   9   1
# 19   0.465011  [Yes, more or less.  We werent able to project...  20   4
# 20   0.390175  [Yes, you see how well that went. [laughter] N...   4   1
# 21   0.462387  [Well, I always wondered where that number cam...   3   1
# 22   0.464781  [Believe it or not, I was on the "better more ...   7   4
# 23   0.480215  [Well, the vast majority of them really dont k...   5   5
# 24   0.501119  [Well, ballroom dancing, like any other partne...  18   9
# 25   0.472054  [Well, I think it turns out the truth is stran...   4   2
# 26   0.453701  [The trick is you make the pre-dinner prayer o...   6   4
# 27   0.488553  [I went to Calcutta at the age of 16, very bra...   8   2
# 28   0.422437  [Well first of all I agree with Steve, why wou...   3   2
# 29   0.411544  [It says I was broke.  I was a volunteer think...  13   5
# ..        ...                                                ...  ..  ..
# 77   0.459538  [Thank you.  [APPLAUSE]  Thank you all very mu...   5  10
# 78   0.403208  [Thank you very much.  [APPLAUSE]  I have to t...   6   8
# 79   0.447109  [Thank you very much.  Thank you.  Thank you v...   8   8
# 80   0.491712  [Both sides, two Theyre all rolling over in th...  15   9
# 81   0.428699  [I havent said anything yet. [AUDIENCE VOICES]...  24  15
# 82   0.497240  [Thank you, John.  [APPLAUSE]  Well, this is s...  29   9
# 83   0.473112  [Wow.  Philip, you ought to be a preacher.  [L...   6  17
# 84   0.491535  [Well, thanks, John, Im still happy to argue t...  15  13
# 85   0.505286  [Yes.  Uh  [LAUGHTER, APPLAUSE]  So I was goin...  19   6
# 86   0.493925  [Thank you very much, its a great pleasure to ...   7   4
# 87   0.469086  [Thank you very much, I made this film actuall...   5   3
# 88   0.429073  [Thank you.  We do have a moral obligation to ...  11   1
# 89   0.495177  [Defenders of markets for organs often charge ...   4   1
# 90   0.485372  [There is something peculiar about the way tha...   6   4
# 91   0.527507  [Some, some have been some have been prosecute...  18   3
# 92   0.455420  [Good evening.  Delighted to be here.  Let me ...  10   6
# 93   0.461941  [Dont start my timer.  Hes from St. Louis, hes...   5   1
# 94   0.410512  [Good evening.  For a moment, I thought George...   4   3
# 95   0.470916  [Well, one thing that John McWhorters right ab...   3   4
# 96   0.391213  [Thank you very much, thank you Rosenkranz Fou...   1   4
# 97   0.467402  [Well, thank you, everybody, for coming out to...   2   1
# 98   0.421442  [Uh, there are clearly a number of issues that...   2   3
# 99   0.444295  [Well I, my name is Jim McGregor and Ive lived...   9   1
# 100  0.473427  [I promisenot to use the example that David ga...   8   4
# 101  0.446350  [Id like to thank the Rosenkranz Foundation, t...  14   6
# 102  0.442277  [America is too damn religious.  Says who?  We...   7   9
# 103  0.478922  [I wanted to take ten seconds of my time for a...   6   9
# 104  0.454969  [I would like to thank everyone for the invita...   0   6
# 105  0.489633  [Right.  Well   [LAUGHTER]  First of all I wan...   3   4
# 106  0.417855  [I thought George gave a very eloquent stateme...   9   2
#
#            AP        AS  did_for_the_motion_win
# 0    0.048558  0.529580                       0
# 1    0.154359  0.473533                       0
# 2    0.094059  0.454252                       0
# 3    0.029759  0.494038                       0
# 4    0.110871  0.392046                       0
# 5    0.104100  0.530115                       0
# 6    0.138616  0.515113                       1
# 7    0.098789  0.426898                       1
# 8    0.163176  0.545184                       0
# 9    0.131103  0.495310                       1
# 10   0.072180  0.482544                       0
# 11   0.128939  0.430481                       0
# 12   0.131025  0.469511                       1
# 13   0.058621  0.430702                       1
# 14   0.025331  0.469532                       1
# 15   0.152407  0.469690                       0
# 16   0.108371  0.543969                       0
# 17   0.145505  0.445630                       1
# 18   0.154771  0.501200                       1
# 19   0.065110  0.452952                       0
# 20   0.057062  0.414985                       1
# 21   0.190246  0.467191                       1
# 22   0.120905  0.465184                       1
# 23   0.107550  0.468317                       1
# 24   0.135543  0.499983                       1
# 25   0.077827  0.487769                       0
# 26   0.092277  0.465869                       1
# 27   0.128169  0.473622                       0
# 28   0.130556  0.394055                       1
# 29   0.079970  0.433422                       0
# ..        ...       ...                     ...
# 77   0.132390  0.471616                       0
# 78   0.099324  0.456022                       1
# 79   0.128230  0.464863                       0
# 80   0.065784  0.498597                       1
# 81   0.100250  0.455551                       1
# 82   0.142733  0.514406                       1
# 83   0.110497  0.441996                       1
# 84   0.085226  0.501362                       0
# 85   0.040242  0.578460                       1
# 86   0.102391  0.477875                       1
# 87   0.074442  0.467521                       1
# 88   0.083039  0.427700                       0
# 89   0.105066  0.491670                       1
# 90   0.089763  0.412463                       1
# 91   0.108606  0.491611                       0
# 92   0.120436  0.431234                       1
# 93   0.084075  0.466370                       1
# 94   0.116723  0.458894                       0
# 95   0.157033  0.441878                       0
# 96   0.065317  0.460985                       0
# 97   0.097174  0.433929                       1
# 98   0.126054  0.457163                       1
# 99   0.112589  0.415329                       0
# 100  0.087384  0.491133                       0
# 101  0.106239  0.463121                       1
# 102  0.106407  0.444310                       1
# 103  0.083292  0.504105                       0
# 104  0.070512  0.413741                       0
# 105  0.075404  0.498779                       1
# 106  0.098142  0.516591                       1
#
# [107 rows x 11 columns]

# %%
    
all_text = [' '.join(item) for item in all_text]
tfidf = TfidfVectorizer(stop_words = 'english')
tfidf_vectors = tfidf.fit_transform(all_text)
tfidf_vectors = tfidf_vectors.todense()

vector_differences = [] 

for x in range(107): 
    vector_differences.append(tfidf_vectors[x] - tfidf_vectors[x+107])

df['Vector_differences'] = vector_differences

# %%
for_the_motion_win_classification = []
for item in names_and_win: 
    for_the_motion_win_classification.append(item[1][0])
    
df['did_for_the_motion_win'] = for_the_motion_win_classification

# %%
df.columns
# Out:
# Index([u'For_text', u'FL', u'FA', u'FP', u'FS', u'Against_text', u'AL', u'AA',
#        u'AP', u'AS', u'did_for_the_motion_win'],
#       dtype='object')

# %%
X = df.drop(['For_text', 'Against_text', 'did_for_the_motion_win'], axis=1)

# %%
y = df['did_for_the_motion_win']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)

# %%
lr.score(X_test, y_test)
# Out:
# 0.59259259259259256

# %%
y_hat = lr.predict(X_test)

# %%
f1_score(y_test, y_hat)
# Out:
# 0.64516129032258063

# %%
rf = RandomForestClassifier(n_estimators = 1000)

# %%
fittedrf = rf.fit(X_train, y_train)

# %%
y_hat_rf = fittedrf.predict(X_test)

# %%
f1_score(y_test, y_hat_rf)
# Out:
# 0.57142857142857151
